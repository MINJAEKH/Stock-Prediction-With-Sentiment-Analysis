# %% [markdown]
# 본 수정 파일

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.10/dist-packages (0.9.66)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.11.17)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)

# %%
import os
import pandas as pd
import re
import FinanceDataReader as fdr
from datetime import datetime, timedelta
import calendar
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten
from keras.layers import *
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/23-2 창의적종합설계 /LSTM/231205/eco_merged_f.csv')
df.head()
# Out:
#          Date    Open    High     Low   Close   Volume    Change  \
# 0  2023-02-01  123500  129500  123500  128400   569539  0.045603
# 1  2023-02-02  130500  132000  129400  131000   451433  0.020249
# 2  2023-02-03  130800  142200  129100  137600  1194656  0.050382
# 3  2023-02-06  138500  149000  138200  146200  1350414  0.062500
# 4  2023-02-07  147200  178100  147000  165900  3892423  0.134747
#
#    news_prob_scaled  jongto_prob_scaled  pax_prob_scaled
# 0          0.720895            0.588008         0.500000
# 1          0.719629            0.592710         0.500000
# 2          0.744021            0.582911         0.500000
# 3          0.709026            0.624390         0.500000
# 4          0.716227            0.557894         0.268041

# %% [markdown]
# ### 전처리 및 Window Dataset

# %%
df.drop(['Date'], axis=1)
df
# df = df.drop(['Date'], axis=1)
# Out:
#            Date     Open     High      Low    Close   Volume    Change  \
# 0    2023-02-01   123500   129500   123500   128400   569539  0.045603
# 1    2023-02-02   130500   132000   129400   131000   451433  0.020249
# 2    2023-02-03   130800   142200   129100   137600  1194656  0.050382
# 3    2023-02-06   138500   149000   138200   146200  1350414  0.062500
# 4    2023-02-07   147200   178100   147000   165900  3892423  0.134747
# ..          ...      ...      ...      ...      ...      ...       ...
# 119  2023-07-25  1148000  1321000  1120000  1293000  2074447  0.113695
# 120  2023-07-26  1303000  1539000  1136000  1228000  3016645 -0.050271
# 121  2023-07-27  1200000  1200000   961000   985000  2847371 -0.197883
# 122  2023-07-28   956000  1111000   935000  1104000  2058139  0.120812
# 123  2023-07-31  1136000  1224000  1125000  1207000  1331266  0.093297
#
#      news_prob_scaled  jongto_prob_scaled  pax_prob_scaled
# 0            0.720895            0.588008         0.500000
# 1            0.719629            0.592710         0.500000
# 2            0.744021            0.582911         0.500000
# 3            0.709026            0.624390         0.500000
# 4            0.716227            0.557894         0.268041
# ..                ...                 ...              ...
# 119          0.724845            0.601424         0.246811
# 120          0.733201            0.581307         0.370817
# 121          0.723892            0.579328         0.329509
# 122          0.747329            0.596435         0.283428
# 123          0.741940            0.595050         0.170606
#
# [124 rows x 10 columns]

# %%
# df.drop('news_prob_scaled', axis=1, inplace=True)
df.drop('jongto_prob_scaled', axis=1, inplace=True)
df.drop('pax_prob_scaled', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Change',
#        'news_prob_scaled'],
#       dtype='object')

# %%
df = df.drop(["Date"],axis = 1)
y = df["Close"]
x = df.drop("Close",axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0, shuffle=False)

# %%
train = pd.concat([x_train,y_train], axis=1)
test = pd.concat([x_test,y_test], axis=1)

# %%
sc = MinMaxScaler()
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume']

train[scale_cols] = sc.fit_transform(train[scale_cols])
test[scale_cols] = sc.transform(test[scale_cols])

# %%
# many2many -> outpu_window size = 1로 함수 수정
def windowDataset(df, window_size, batch_size, shuffle) :
    x = df.drop("Close",axis=1)
    y = df["Close"]
    ds_x = tf.data.Dataset.from_tensor_slices(x)
    ds_x = ds_x.window(window_size, stride = 1, shift = 1, drop_remainder = True)
    ds_x = ds_x.flat_map(lambda x: x.batch(window_size))

    ds_y = tf.data.Dataset.from_tensor_slices([y[i:i+1].values for i in range(window_size, len(y)-1)])

    data = tf.data.Dataset.zip((ds_x,ds_y))

    #if shuffle :
        #data = data.shuffle(10)

    return data.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=3
BATCH_SIZE=1
ratio = int(len(train) * 0.8)

train_data = windowDataset(train[:ratio], WINDOW_SIZE, BATCH_SIZE, shuffle= True)
val_data = windowDataset(train[ratio:], WINDOW_SIZE, BATCH_SIZE, shuffle = False)
test_data = windowDataset(test, WINDOW_SIZE, BATCH_SIZE, shuffle = False)

# %%
for data in train_data.take(1):
    print(f'학습 데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'학습 데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 학습 데이터셋(X) 구성(batch_size, window_size, feature갯수): (1, 3, 6)
# 학습 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (1, 1)

# %%
train_data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 6), dtype=tf.float64, name=None), TensorSpec(shape=(None, 1), dtype=tf.float64, name=None))>

# %%
len(test)
# Out:
# 25

# %% [markdown]
# ### LSTM

# %%
model = Sequential([
    # 1차원 feature map 생성
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[None, 6]),
    # LSTM
    LSTM(64, activation='relu', return_sequences=True),
    LSTM(32, activation='relu', return_sequences=False),
    Dense(16, activation="relu"),
    Dense(1),
])

# %%
loss = Huber()
optimizer = Adam(0.0001)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# %%
history = model.fit(train_data,
                    validation_data=(val_data),
                    epochs=100,
                    callbacks=[checkpoint, earlystopping]
                    )
# Out:
# Epoch 1/100
#      70/Unknown - 8s 14ms/step - loss: 0.1355 - mse: 0.2710
# Epoch 1: val_loss improved from inf to 0.31114, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 10s 31ms/step - loss: 0.1381 - mse: 0.2761 - val_loss: 0.3111 - val_mse: 0.6223
# Epoch 2/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0958 - mse: 0.1915
# Epoch 2: val_loss improved from 0.31114 to 0.20613, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 14ms/step - loss: 0.0965 - mse: 0.1929 - val_loss: 0.2061 - val_mse: 0.4123
# Epoch 3/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0365 - mse: 0.0730
# Epoch 3: val_loss improved from 0.20613 to 0.04335, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0365 - mse: 0.0730 - val_loss: 0.0434 - val_mse: 0.0867
# Epoch 4/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0146 - mse: 0.0293
# Epoch 4: val_loss improved from 0.04335 to 0.00866, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0139 - mse: 0.0279 - val_loss: 0.0087 - val_mse: 0.0173
# Epoch 5/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0149 - mse: 0.0297
# Epoch 5: val_loss improved from 0.00866 to 0.00825, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 14ms/step - loss: 0.0145 - mse: 0.0291 - val_loss: 0.0082 - val_mse: 0.0165
# Epoch 6/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0127 - mse: 0.0255
# Epoch 6: val_loss improved from 0.00825 to 0.00752, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0123 - mse: 0.0246 - val_loss: 0.0075 - val_mse: 0.0150
# Epoch 7/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0110 - mse: 0.0220
# Epoch 7: val_loss improved from 0.00752 to 0.00719, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 14ms/step - loss: 0.0108 - mse: 0.0215 - val_loss: 0.0072 - val_mse: 0.0144
# Epoch 8/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0097 - mse: 0.0195
# Epoch 8: val_loss improved from 0.00719 to 0.00680, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 14ms/step - loss: 0.0095 - mse: 0.0191 - val_loss: 0.0068 - val_mse: 0.0136
# Epoch 9/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0090 - mse: 0.0180
# Epoch 9: val_loss improved from 0.00680 to 0.00670, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 20ms/step - loss: 0.0086 - mse: 0.0172 - val_loss: 0.0067 - val_mse: 0.0134
# Epoch 10/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0079 - mse: 0.0158
# Epoch 10: val_loss improved from 0.00670 to 0.00656, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0078 - mse: 0.0156 - val_loss: 0.0066 - val_mse: 0.0131
# Epoch 11/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0073 - mse: 0.0145
# Epoch 11: val_loss improved from 0.00656 to 0.00646, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0072 - mse: 0.0144 - val_loss: 0.0065 - val_mse: 0.0129
# Epoch 12/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0068 - mse: 0.0137
# Epoch 12: val_loss improved from 0.00646 to 0.00634, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 2s 21ms/step - loss: 0.0067 - mse: 0.0134 - val_loss: 0.0063 - val_mse: 0.0127
# Epoch 13/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0063 - mse: 0.0126
# Epoch 13: val_loss improved from 0.00634 to 0.00629, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0063 - mse: 0.0126 - val_loss: 0.0063 - val_mse: 0.0126
# Epoch 14/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0061 - mse: 0.0122
# Epoch 14: val_loss improved from 0.00629 to 0.00619, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0060 - mse: 0.0120 - val_loss: 0.0062 - val_mse: 0.0124
# Epoch 15/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0057 - mse: 0.0115
# Epoch 15: val_loss improved from 0.00619 to 0.00611, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0057 - mse: 0.0115 - val_loss: 0.0061 - val_mse: 0.0122
# Epoch 16/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0058 - mse: 0.0116
# Epoch 16: val_loss improved from 0.00611 to 0.00601, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0055 - mse: 0.0110 - val_loss: 0.0060 - val_mse: 0.0120
# Epoch 17/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0056 - mse: 0.0112
# Epoch 17: val_loss improved from 0.00601 to 0.00592, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0053 - mse: 0.0106 - val_loss: 0.0059 - val_mse: 0.0118
# Epoch 18/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0056 - mse: 0.0112
# Epoch 18: val_loss improved from 0.00592 to 0.00580, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0052 - mse: 0.0103 - val_loss: 0.0058 - val_mse: 0.0116
# Epoch 19/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0052 - mse: 0.0103
# Epoch 19: val_loss improved from 0.00580 to 0.00571, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0050 - mse: 0.0101 - val_loss: 0.0057 - val_mse: 0.0114
# Epoch 20/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0051 - mse: 0.0102
# Epoch 20: val_loss improved from 0.00571 to 0.00565, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0049 - mse: 0.0098 - val_loss: 0.0057 - val_mse: 0.0113
# Epoch 21/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0049 - mse: 0.0097
# Epoch 21: val_loss improved from 0.00565 to 0.00557, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0048 - mse: 0.0095 - val_loss: 0.0056 - val_mse: 0.0111
# Epoch 22/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0048 - mse: 0.0096
# Epoch 22: val_loss improved from 0.00557 to 0.00551, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0046 - mse: 0.0093 - val_loss: 0.0055 - val_mse: 0.0110
# Epoch 23/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0047 - mse: 0.0093
# Epoch 23: val_loss improved from 0.00551 to 0.00543, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0045 - mse: 0.0090 - val_loss: 0.0054 - val_mse: 0.0109
# Epoch 24/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0045 - mse: 0.0090
# Epoch 24: val_loss improved from 0.00543 to 0.00535, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0044 - mse: 0.0088 - val_loss: 0.0054 - val_mse: 0.0107
# Epoch 25/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0044 - mse: 0.0088
# Epoch 25: val_loss improved from 0.00535 to 0.00528, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0043 - mse: 0.0086 - val_loss: 0.0053 - val_mse: 0.0106
# Epoch 26/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0086
# Epoch 26: val_loss improved from 0.00528 to 0.00522, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0042 - mse: 0.0084 - val_loss: 0.0052 - val_mse: 0.0104
# Epoch 27/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0044 - mse: 0.0088
# Epoch 27: val_loss improved from 0.00522 to 0.00520, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0041 - mse: 0.0082 - val_loss: 0.0052 - val_mse: 0.0104
# Epoch 28/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0041 - mse: 0.0083
# Epoch 28: val_loss did not improve from 0.00520
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0039 - mse: 0.0078 - val_loss: 0.0053 - val_mse: 0.0105
# Epoch 29/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0039 - mse: 0.0079
# Epoch 29: val_loss improved from 0.00520 to 0.00512, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0038 - mse: 0.0076 - val_loss: 0.0051 - val_mse: 0.0102
# Epoch 30/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0038 - mse: 0.0077
# Epoch 30: val_loss improved from 0.00512 to 0.00512, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0037 - mse: 0.0075 - val_loss: 0.0051 - val_mse: 0.0102
# Epoch 31/100
# 69/75 [==========================>...] - ETA: 0s - loss: 0.0039 - mse: 0.0078
# Epoch 31: val_loss improved from 0.00512 to 0.00505, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0037 - mse: 0.0073 - val_loss: 0.0051 - val_mse: 0.0101
# Epoch 32/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0037 - mse: 0.0075
# Epoch 32: val_loss improved from 0.00505 to 0.00504, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0036 - mse: 0.0071 - val_loss: 0.0050 - val_mse: 0.0101
# Epoch 33/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0036 - mse: 0.0072
# Epoch 33: val_loss improved from 0.00504 to 0.00501, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0035 - mse: 0.0070 - val_loss: 0.0050 - val_mse: 0.0100
# Epoch 34/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0035 - mse: 0.0070
# Epoch 34: val_loss improved from 0.00501 to 0.00500, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0034 - mse: 0.0068 - val_loss: 0.0050 - val_mse: 0.0100
# Epoch 35/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0035 - mse: 0.0070
# Epoch 35: val_loss improved from 0.00500 to 0.00496, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0034 - mse: 0.0067 - val_loss: 0.0050 - val_mse: 0.0099
# Epoch 36/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0033 - mse: 0.0066
# Epoch 36: val_loss improved from 0.00496 to 0.00495, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0033 - mse: 0.0066 - val_loss: 0.0050 - val_mse: 0.0099
# Epoch 37/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0034 - mse: 0.0068
# Epoch 37: val_loss improved from 0.00495 to 0.00493, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0032 - mse: 0.0065 - val_loss: 0.0049 - val_mse: 0.0099
# Epoch 38/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0033 - mse: 0.0067
# Epoch 38: val_loss improved from 0.00493 to 0.00492, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0032 - mse: 0.0064 - val_loss: 0.0049 - val_mse: 0.0098
# Epoch 39/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0033 - mse: 0.0067
# Epoch 39: val_loss did not improve from 0.00492
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0031 - mse: 0.0063 - val_loss: 0.0049 - val_mse: 0.0099
# Epoch 40/100
# 69/75 [==========================>...] - ETA: 0s - loss: 0.0033 - mse: 0.0067
# Epoch 40: val_loss improved from 0.00492 to 0.00491, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0031 - mse: 0.0062 - val_loss: 0.0049 - val_mse: 0.0098
# Epoch 41/100
# 68/75 [==========================>...] - ETA: 0s - loss: 0.0033 - mse: 0.0067
# Epoch 41: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0061 - val_loss: 0.0049 - val_mse: 0.0098
# Epoch 42/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0060
# Epoch 42: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0030 - mse: 0.0060 - val_loss: 0.0049 - val_mse: 0.0099
# Epoch 43/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0031 - mse: 0.0062
# Epoch 43: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0030 - mse: 0.0060 - val_loss: 0.0050 - val_mse: 0.0099
# Epoch 44/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0030 - mse: 0.0061
# Epoch 44: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0030 - mse: 0.0059 - val_loss: 0.0050 - val_mse: 0.0099
# Epoch 45/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0031 - mse: 0.0061
# Epoch 45: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0029 - mse: 0.0059 - val_loss: 0.0050 - val_mse: 0.0099
# Epoch 46/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0031 - mse: 0.0062
# Epoch 46: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0049 - val_mse: 0.0099
# Epoch 47/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0029 - mse: 0.0058
# Epoch 47: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0029 - mse: 0.0057 - val_loss: 0.0050 - val_mse: 0.0099
# Epoch 48/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0030 - mse: 0.0060
# Epoch 48: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0029 - mse: 0.0057 - val_loss: 0.0049 - val_mse: 0.0099
# Epoch 49/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0030 - mse: 0.0059
# Epoch 49: val_loss did not improve from 0.00491
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0049 - val_mse: 0.0099
# Epoch 50/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0029 - mse: 0.0057
# Epoch 50: val_loss did not improve from 0.00491
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0050 - val_mse: 0.0099

# %%
model.load_weights(filename)

# %%
pred = model.predict(test_data)
# Out:
# 21/21 [==============================] - 0s 4ms/step

# %%
pred.shape
# Out:
# (21, 1)

# %%
pred
# Out:
# array([[0.8609661],
#        [0.8572347],
#        [0.9039544],
#        [1.0059383],
#        [1.0992994],
#        [1.1499803],
#        [1.1709753],
#        [1.2034194],
#        [1.2154678],
#        [1.2189919],
#        [1.1915846],
#        [1.1857754],
#        [1.19561  ],
#        [1.2662059],
#        [1.3472972],
#        [1.4024566],
#        [1.4115937],
#        [1.4398731],
#        [1.5354563],
#        [1.6797127],
#        [1.6909944]], dtype=float32)

# %%
plt.figure(figsize=(8, 6))
plt.plot(np.asarray(test['Close'])[5:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
score = model.evaluate(test_data)
score
# Out:
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0241 - mse: 0.0483
# [0.024139419198036194, 0.04827883839607239]
