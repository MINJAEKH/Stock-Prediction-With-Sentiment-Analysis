# %% [markdown]
# 본 수정 파일

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.10/dist-packages (0.9.66)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.11.17)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)

# %%
import os
import pandas as pd
import re
import FinanceDataReader as fdr
from datetime import datetime, timedelta
import calendar
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten
from keras.layers import *
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/23-2 창의적종합설계 /LSTM/231205/eco_merged_f.csv')
df.head()
# Out:
#          Date    Open    High     Low   Close   Volume    Change  \
# 0  2023-02-01  123500  129500  123500  128400   569539  0.045603
# 1  2023-02-02  130500  132000  129400  131000   451433  0.020249
# 2  2023-02-03  130800  142200  129100  137600  1194656  0.050382
# 3  2023-02-06  138500  149000  138200  146200  1350414  0.062500
# 4  2023-02-07  147200  178100  147000  165900  3892423  0.134747
#
#    news_prob_scaled  jongto_prob_scaled  pax_prob_scaled
# 0          0.720895            0.588008         0.500000
# 1          0.719629            0.592710         0.500000
# 2          0.744021            0.582911         0.500000
# 3          0.709026            0.624390         0.500000
# 4          0.716227            0.557894         0.268041

# %% [markdown]
# ### 전처리 및 Window Dataset

# %%
df.drop(['Date'], axis=1)
df
# df = df.drop(['Date'], axis=1)
# Out:
#            Date     Open     High      Low    Close   Volume    Change  \
# 0    2023-02-01   123500   129500   123500   128400   569539  0.045603
# 1    2023-02-02   130500   132000   129400   131000   451433  0.020249
# 2    2023-02-03   130800   142200   129100   137600  1194656  0.050382
# 3    2023-02-06   138500   149000   138200   146200  1350414  0.062500
# 4    2023-02-07   147200   178100   147000   165900  3892423  0.134747
# ..          ...      ...      ...      ...      ...      ...       ...
# 119  2023-07-25  1148000  1321000  1120000  1293000  2074447  0.113695
# 120  2023-07-26  1303000  1539000  1136000  1228000  3016645 -0.050271
# 121  2023-07-27  1200000  1200000   961000   985000  2847371 -0.197883
# 122  2023-07-28   956000  1111000   935000  1104000  2058139  0.120812
# 123  2023-07-31  1136000  1224000  1125000  1207000  1331266  0.093297
#
#      news_prob_scaled  jongto_prob_scaled  pax_prob_scaled
# 0            0.720895            0.588008         0.500000
# 1            0.719629            0.592710         0.500000
# 2            0.744021            0.582911         0.500000
# 3            0.709026            0.624390         0.500000
# 4            0.716227            0.557894         0.268041
# ..                ...                 ...              ...
# 119          0.724845            0.601424         0.246811
# 120          0.733201            0.581307         0.370817
# 121          0.723892            0.579328         0.329509
# 122          0.747329            0.596435         0.283428
# 123          0.741940            0.595050         0.170606
#
# [124 rows x 10 columns]

# %%
df.drop('news_prob_scaled', axis=1, inplace=True)
# df.drop('jongto_prob_scaled', axis=1, inplace=True)
df.drop('pax_prob_scaled', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Change',
#        'jongto_prob_scaled'],
#       dtype='object')

# %%
df = df.drop(["Date"],axis = 1)
y = df["Close"]
x = df.drop("Close",axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0, shuffle=False)

# %%
train = pd.concat([x_train,y_train], axis=1)
test = pd.concat([x_test,y_test], axis=1)

# %%
sc = MinMaxScaler()
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume']

train[scale_cols] = sc.fit_transform(train[scale_cols])
test[scale_cols] = sc.transform(test[scale_cols])

# %%
# many2many -> outpu_window size = 1로 함수 수정
def windowDataset(df, window_size, batch_size, shuffle) :
    x = df.drop("Close",axis=1)
    y = df["Close"]
    ds_x = tf.data.Dataset.from_tensor_slices(x)
    ds_x = ds_x.window(window_size, stride = 1, shift = 1, drop_remainder = True)
    ds_x = ds_x.flat_map(lambda x: x.batch(window_size))

    ds_y = tf.data.Dataset.from_tensor_slices([y[i:i+1].values for i in range(window_size, len(y)-1)])

    data = tf.data.Dataset.zip((ds_x,ds_y))

    #if shuffle :
        #data = data.shuffle(10)

    return data.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=3
BATCH_SIZE=1
ratio = int(len(train) * 0.8)

train_data = windowDataset(train[:ratio], WINDOW_SIZE, BATCH_SIZE, shuffle= True)
val_data = windowDataset(train[ratio:], WINDOW_SIZE, BATCH_SIZE, shuffle = False)
test_data = windowDataset(test, WINDOW_SIZE, BATCH_SIZE, shuffle = False)

# %%
for data in train_data.take(1):
    print(f'학습 데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'학습 데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 학습 데이터셋(X) 구성(batch_size, window_size, feature갯수): (1, 3, 6)
# 학습 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (1, 1)

# %%
train_data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 6), dtype=tf.float64, name=None), TensorSpec(shape=(None, 1), dtype=tf.float64, name=None))>

# %%
len(test)
# Out:
# 25

# %% [markdown]
# ### LSTM

# %%
model = Sequential([
    # 1차원 feature map 생성
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[None, 6]),
    # LSTM
    LSTM(64, activation='relu', return_sequences=True),
    LSTM(32, activation='relu', return_sequences=False),
    Dense(16, activation="relu"),
    Dense(1),
])

# %%
loss = Huber()
optimizer = Adam(0.0001)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# %%
history = model.fit(train_data,
                    validation_data=(val_data),
                    epochs=100,
                    callbacks=[checkpoint, earlystopping]
                    )
# Out:
# Epoch 1/100
#      73/Unknown - 4s 9ms/step - loss: 0.1323 - mse: 0.2646
# Epoch 1: val_loss improved from inf to 0.29343, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 5s 24ms/step - loss: 0.1333 - mse: 0.2666 - val_loss: 0.2934 - val_mse: 0.5869
# Epoch 2/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0848 - mse: 0.1696
# Epoch 2: val_loss improved from 0.29343 to 0.16908, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0850 - mse: 0.1700 - val_loss: 0.1691 - val_mse: 0.3382
# Epoch 3/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0263 - mse: 0.0526
# Epoch 3: val_loss improved from 0.16908 to 0.02326, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0261 - mse: 0.0522 - val_loss: 0.0233 - val_mse: 0.0465
# Epoch 4/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0119 - mse: 0.0239
# Epoch 4: val_loss improved from 0.02326 to 0.00718, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0119 - mse: 0.0239 - val_loss: 0.0072 - val_mse: 0.0144
# Epoch 5/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0115 - mse: 0.0229
# Epoch 5: val_loss improved from 0.00718 to 0.00697, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0115 - mse: 0.0229 - val_loss: 0.0070 - val_mse: 0.0139
# Epoch 6/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0103 - mse: 0.0206
# Epoch 6: val_loss improved from 0.00697 to 0.00676, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 20ms/step - loss: 0.0101 - mse: 0.0202 - val_loss: 0.0068 - val_mse: 0.0135
# Epoch 7/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0091 - mse: 0.0183
# Epoch 7: val_loss improved from 0.00676 to 0.00661, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0090 - mse: 0.0179 - val_loss: 0.0066 - val_mse: 0.0132
# Epoch 8/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0080 - mse: 0.0161
# Epoch 8: val_loss improved from 0.00661 to 0.00650, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0080 - mse: 0.0160 - val_loss: 0.0065 - val_mse: 0.0130
# Epoch 9/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0074 - mse: 0.0149
# Epoch 9: val_loss improved from 0.00650 to 0.00644, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0072 - mse: 0.0143 - val_loss: 0.0064 - val_mse: 0.0129
# Epoch 10/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0065 - mse: 0.0130
# Epoch 10: val_loss improved from 0.00644 to 0.00640, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0065 - mse: 0.0129 - val_loss: 0.0064 - val_mse: 0.0128
# Epoch 11/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0062 - mse: 0.0124
# Epoch 11: val_loss improved from 0.00640 to 0.00633, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0059 - mse: 0.0118 - val_loss: 0.0063 - val_mse: 0.0127
# Epoch 12/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0055 - mse: 0.0110
# Epoch 12: val_loss improved from 0.00633 to 0.00623, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 14ms/step - loss: 0.0055 - mse: 0.0110 - val_loss: 0.0062 - val_mse: 0.0125
# Epoch 13/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0052 - mse: 0.0104
# Epoch 13: val_loss improved from 0.00623 to 0.00615, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0051 - mse: 0.0103 - val_loss: 0.0062 - val_mse: 0.0123
# Epoch 14/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0050 - mse: 0.0101
# Epoch 14: val_loss improved from 0.00615 to 0.00606, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0049 - mse: 0.0097 - val_loss: 0.0061 - val_mse: 0.0121
# Epoch 15/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0047 - mse: 0.0094
# Epoch 15: val_loss improved from 0.00606 to 0.00594, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 2s 25ms/step - loss: 0.0047 - mse: 0.0093 - val_loss: 0.0059 - val_mse: 0.0119
# Epoch 16/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0045 - mse: 0.0091
# Epoch 16: val_loss improved from 0.00594 to 0.00581, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0045 - mse: 0.0090 - val_loss: 0.0058 - val_mse: 0.0116
# Epoch 17/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0044 - mse: 0.0088
# Epoch 17: val_loss improved from 0.00581 to 0.00569, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0043 - mse: 0.0087 - val_loss: 0.0057 - val_mse: 0.0114
# Epoch 18/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0042 - mse: 0.0085
# Epoch 18: val_loss improved from 0.00569 to 0.00559, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0042 - mse: 0.0084 - val_loss: 0.0056 - val_mse: 0.0112
# Epoch 19/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0042 - mse: 0.0084
# Epoch 19: val_loss improved from 0.00559 to 0.00550, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0041 - mse: 0.0082 - val_loss: 0.0055 - val_mse: 0.0110
# Epoch 20/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0040 - mse: 0.0079
# Epoch 20: val_loss improved from 0.00550 to 0.00542, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0040 - mse: 0.0079 - val_loss: 0.0054 - val_mse: 0.0108
# Epoch 21/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0039 - mse: 0.0077
# Epoch 21: val_loss improved from 0.00542 to 0.00535, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0039 - mse: 0.0077 - val_loss: 0.0054 - val_mse: 0.0107
# Epoch 22/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0039 - mse: 0.0078
# Epoch 22: val_loss improved from 0.00535 to 0.00530, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0038 - mse: 0.0075 - val_loss: 0.0053 - val_mse: 0.0106
# Epoch 23/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0037 - mse: 0.0075
# Epoch 23: val_loss improved from 0.00530 to 0.00524, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0037 - mse: 0.0074 - val_loss: 0.0052 - val_mse: 0.0105
# Epoch 24/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0038 - mse: 0.0077
# Epoch 24: val_loss improved from 0.00524 to 0.00518, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0036 - mse: 0.0072 - val_loss: 0.0052 - val_mse: 0.0104
# Epoch 25/100
# 69/75 [==========================>...] - ETA: 0s - loss: 0.0037 - mse: 0.0075
# Epoch 25: val_loss improved from 0.00518 to 0.00514, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0035 - mse: 0.0071 - val_loss: 0.0051 - val_mse: 0.0103
# Epoch 26/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0036 - mse: 0.0071
# Epoch 26: val_loss improved from 0.00514 to 0.00509, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0035 - mse: 0.0069 - val_loss: 0.0051 - val_mse: 0.0102
# Epoch 27/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0035 - mse: 0.0071
# Epoch 27: val_loss improved from 0.00509 to 0.00506, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0034 - mse: 0.0068 - val_loss: 0.0051 - val_mse: 0.0101
# Epoch 28/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0034 - mse: 0.0069
# Epoch 28: val_loss improved from 0.00506 to 0.00503, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0033 - mse: 0.0067 - val_loss: 0.0050 - val_mse: 0.0101
# Epoch 29/100
# 69/75 [==========================>...] - ETA: 0s - loss: 0.0035 - mse: 0.0070
# Epoch 29: val_loss did not improve from 0.00503
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0033 - mse: 0.0065 - val_loss: 0.0054 - val_mse: 0.0107
# Epoch 30/100
# 66/75 [=========================>....] - ETA: 0s - loss: 0.0034 - mse: 0.0068
# Epoch 30: val_loss did not improve from 0.00503
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0032 - mse: 0.0065 - val_loss: 0.0051 - val_mse: 0.0102
# Epoch 31/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0032 - mse: 0.0064
# Epoch 31: val_loss did not improve from 0.00503
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0032 - mse: 0.0064 - val_loss: 0.0051 - val_mse: 0.0101
# Epoch 32/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0032 - mse: 0.0063
# Epoch 32: val_loss improved from 0.00503 to 0.00502, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0031 - mse: 0.0063 - val_loss: 0.0050 - val_mse: 0.0100
# Epoch 33/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0033 - mse: 0.0066
# Epoch 33: val_loss improved from 0.00502 to 0.00499, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0031 - mse: 0.0062 - val_loss: 0.0050 - val_mse: 0.0100
# Epoch 34/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0031 - mse: 0.0062
# Epoch 34: val_loss improved from 0.00499 to 0.00496, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0031 - mse: 0.0061 - val_loss: 0.0050 - val_mse: 0.0099
# Epoch 35/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0031 - mse: 0.0061
# Epoch 35: val_loss improved from 0.00496 to 0.00495, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0030 - mse: 0.0060 - val_loss: 0.0049 - val_mse: 0.0099
# Epoch 36/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0032 - mse: 0.0063
# Epoch 36: val_loss improved from 0.00495 to 0.00494, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0030 - mse: 0.0060 - val_loss: 0.0049 - val_mse: 0.0099
# Epoch 37/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0030 - mse: 0.0060
# Epoch 37: val_loss improved from 0.00494 to 0.00491, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0030 - mse: 0.0059 - val_loss: 0.0049 - val_mse: 0.0098
# Epoch 38/100
# 69/75 [==========================>...] - ETA: 0s - loss: 0.0031 - mse: 0.0063
# Epoch 38: val_loss improved from 0.00491 to 0.00488, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0049 - val_mse: 0.0098
# Epoch 39/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0030 - mse: 0.0060
# Epoch 39: val_loss did not improve from 0.00488
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0049 - val_mse: 0.0098
# Epoch 40/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0030 - mse: 0.0060
# Epoch 40: val_loss improved from 0.00488 to 0.00484, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0048 - val_mse: 0.0097
# Epoch 41/100
# 66/75 [=========================>....] - ETA: 0s - loss: 0.0030 - mse: 0.0059
# Epoch 41: val_loss did not improve from 0.00484
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0028 - mse: 0.0057 - val_loss: 0.0049 - val_mse: 0.0097
# Epoch 42/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0030 - mse: 0.0060
# Epoch 42: val_loss improved from 0.00484 to 0.00480, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0028 - mse: 0.0057 - val_loss: 0.0048 - val_mse: 0.0096
# Epoch 43/100
# 68/75 [==========================>...] - ETA: 0s - loss: 0.0030 - mse: 0.0061
# Epoch 43: val_loss did not improve from 0.00480
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0048 - val_mse: 0.0097
# Epoch 44/100
# 69/75 [==========================>...] - ETA: 0s - loss: 0.0030 - mse: 0.0060
# Epoch 44: val_loss improved from 0.00480 to 0.00478, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0048 - val_mse: 0.0096
# Epoch 45/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0055
# Epoch 45: val_loss did not improve from 0.00478
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0028 - mse: 0.0055 - val_loss: 0.0048 - val_mse: 0.0096
# Epoch 46/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0028 - mse: 0.0056
# Epoch 46: val_loss improved from 0.00478 to 0.00478, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0028 - mse: 0.0055 - val_loss: 0.0048 - val_mse: 0.0096
# Epoch 47/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0029 - mse: 0.0058
# Epoch 47: val_loss improved from 0.00478 to 0.00475, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0028 - mse: 0.0055 - val_loss: 0.0048 - val_mse: 0.0095
# Epoch 48/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0028 - mse: 0.0055
# Epoch 48: val_loss did not improve from 0.00475
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0027 - mse: 0.0054 - val_loss: 0.0048 - val_mse: 0.0095
# Epoch 49/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0029 - mse: 0.0058
# Epoch 49: val_loss did not improve from 0.00475
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0027 - mse: 0.0054 - val_loss: 0.0048 - val_mse: 0.0095
# Epoch 50/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0027 - mse: 0.0054
# Epoch 50: val_loss improved from 0.00475 to 0.00473, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0027 - mse: 0.0054 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 51/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0028 - mse: 0.0057
# Epoch 51: val_loss did not improve from 0.00473
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0027 - mse: 0.0054 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 52/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0028 - mse: 0.0056
# Epoch 52: val_loss improved from 0.00473 to 0.00473, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0027 - mse: 0.0053 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 53/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0028 - mse: 0.0056
# Epoch 53: val_loss did not improve from 0.00473
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0026 - mse: 0.0053 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 54/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0028 - mse: 0.0056
# Epoch 54: val_loss did not improve from 0.00473
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0026 - mse: 0.0053 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 55/100
# 66/75 [=========================>....] - ETA: 0s - loss: 0.0027 - mse: 0.0054
# Epoch 55: val_loss did not improve from 0.00473
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0026 - mse: 0.0052 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 56/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0026 - mse: 0.0053
# Epoch 56: val_loss did not improve from 0.00473
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0026 - mse: 0.0052 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 57/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0027 - mse: 0.0053
# Epoch 57: val_loss did not improve from 0.00473
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0026 - mse: 0.0052 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 58/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0027 - mse: 0.0055
# Epoch 58: val_loss improved from 0.00473 to 0.00470, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0026 - mse: 0.0052 - val_loss: 0.0047 - val_mse: 0.0094
# Epoch 59/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0026 - mse: 0.0053
# Epoch 59: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0026 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 60/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0026 - mse: 0.0052
# Epoch 60: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0026 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0094
# Epoch 61/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0027 - mse: 0.0053
# Epoch 61: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 62/100
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0027 - mse: 0.0054
# Epoch 62: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 63/100
# 68/75 [==========================>...] - ETA: 0s - loss: 0.0027 - mse: 0.0055
# Epoch 63: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 64/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0026 - mse: 0.0051
# Epoch 64: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0094
# Epoch 65/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0026 - mse: 0.0052
# Epoch 65: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 66/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0025 - mse: 0.0051
# Epoch 66: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0094
# Epoch 67/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0026 - mse: 0.0051
# Epoch 67: val_loss improved from 0.00470 to 0.00470, saving model to tmp/ckeckpointer.ckpt
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0025 - mse: 0.0049 - val_loss: 0.0047 - val_mse: 0.0094
# Epoch 68/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0025 - mse: 0.0050
# Epoch 68: val_loss did not improve from 0.00470
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0024 - mse: 0.0049 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 69/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0025 - mse: 0.0050
# Epoch 69: val_loss did not improve from 0.00470
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0024 - mse: 0.0049 - val_loss: 0.0047 - val_mse: 0.0094
# Epoch 70/100
# 66/75 [=========================>....] - ETA: 0s - loss: 0.0025 - mse: 0.0050
# Epoch 70: val_loss did not improve from 0.00470
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 71/100
# 74/75 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0049
# Epoch 71: val_loss did not improve from 0.00470
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 72/100
# 67/75 [=========================>....] - ETA: 0s - loss: 0.0025 - mse: 0.0050
# Epoch 72: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 73/100
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0025 - mse: 0.0049
# Epoch 73: val_loss did not improve from 0.00470
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0024 - mse: 0.0048 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 74/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0048
# Epoch 74: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0024 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 75/100
# 75/75 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0047
# Epoch 75: val_loss did not improve from 0.00470
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0024 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 76/100
# 73/75 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0048
# Epoch 76: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0023 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0095
# Epoch 77/100
# 71/75 [===========================>..] - ETA: 0s - loss: 0.0024 - mse: 0.0049
# Epoch 77: val_loss did not improve from 0.00470
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0023 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0095

# %%
model.load_weights(filename)

# %%
pred = model.predict(test_data)
# Out:
# 21/21 [==============================] - 1s 5ms/step

# %%
pred.shape
# Out:
# (21, 1)

# %%
pred
# Out:
# array([[0.83557105],
#        [0.84210813],
#        [0.92760974],
#        [1.0005193 ],
#        [1.0346992 ],
#        [1.0683457 ],
#        [1.0983721 ],
#        [1.1116437 ],
#        [1.1242176 ],
#        [1.1116581 ],
#        [1.1066124 ],
#        [1.094018  ],
#        [1.1161422 ],
#        [1.1948543 ],
#        [1.2498661 ],
#        [1.2794605 ],
#        [1.2882329 ],
#        [1.316104  ],
#        [1.4006468 ],
#        [1.5275031 ],
#        [1.4799294 ]], dtype=float32)

# %%
plt.figure(figsize=(8, 6))
plt.plot(np.asarray(test['Close'])[5:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
score = model.evaluate(test_data)
score
# Out:
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0372 - mse: 0.0744
# [0.03721093386411667, 0.07442186772823334]
